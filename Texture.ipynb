# %% [markdown]
# ## Texture

# %%
import numpy as np

# %%
from skimage import io

# %%
tex = io.imread("obj/african_head_diffuse.tga")

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(tex)

# %%
tex[0, 0]
# Out:
# array([99, 79, 70], dtype=uint8)

# %%
tc = np.array([
    [[0, 0], [10, 10]] ,
    [[20, 30], [30, 40]]   
] * 2)

tc.shape
# Out:
# (4, 2, 2)

# %%
tex[ [ [[0, 0], [0, 0]] ,  [[0, 0], [0, 0]]  ] ]
# Out:
# array([[[99, 79, 70],
#         [99, 79, 70]],
#
#        [[99, 79, 70],
#         [99, 79, 70]]], dtype=uint8)

# %%
tex[tc.transpose(1, 2, 0).tolist()]
# Out:
# array([[[99, 79, 70],
#         [97, 73, 69],
#         [99, 79, 70],
#         [97, 73, 69]],
#
#        [[99, 79, 70],
#         [96, 73, 65],
#         [99, 79, 70],
#         [96, 73, 65]]], dtype=uint8)

# %%
tc
# Out:
# array([[[ 0,  0],
#         [10, 10]],
#
#        [[20, 30],
#         [30, 40]],
#
#        [[ 0,  0],
#         [10, 10]],
#
#        [[20, 30],
#         [30, 40]]])

# %%
tc = tc* 5 + 5

# %%
tc
# Out:
# array([[[  5,   5],
#         [ 55,  55]],
#
#        [[105, 155],
#         [155, 205]],
#
#        [[  5,   5],
#         [ 55,  55]],
#
#        [[105, 155],
#         [155, 205]]])

# %%
tc.clip([50, 105], [100, 200])
# Out:
# array([[[ 50, 105],
#         [ 55, 105]],
#
#        [[100, 155],
#         [100, 200]],
#
#        [[ 50, 105],
#         [ 55, 105]],
#
#        [[100, 155],
#         [100, 200]]])

# %%
tc = tc.transpose(2, 0, 1)

# %%
tc.clip([50, 105], 100)
# Out:
# array([[[ 50, 105],
#         [100, 105],
#         [ 50, 105],
#         [100, 105]],
#
#        [[ 50, 105],
#         [100, 105],
#         [ 50, 105],
#         [100, 105]]])
